# %%
# 1) Clean conflicting installs
# !pip uninstall -y torch torchvision torchaudio torch-geometric pyg_lib torch_scatter torch_sparse torch_cluster

# 2) Install PyTorch stack (GPU Colab: CUDA 12.1 wheels)
# !pip install -q torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu121

# 3) Install PyG compiled extensions matching torch/cuda
# !pip install -q pyg_lib torch_scatter torch_sparse torch_cluster -f https://data.pyg.org/whl/torch-2.5.1+cu121.html
# !pip install -q torch-geometric==2.6.1


import torch, torch_geometric, torch_scatter
print(torch.__version__, torch.version.cuda)
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# WARNING: Skipping torch-geometric as it is not installed.
# WARNING: Skipping pyg_lib as it is not installed.
# WARNING: Skipping torch_scatter as it is not installed.
# WARNING: Skipping torch_sparse as it is not installed.
# WARNING: Skipping torch_cluster as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 152.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 128.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 108.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 64.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 138.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 48.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 126.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 84.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 158.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 57.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 129.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 74.6 MB/s eta 0:00:00
# 2.5.1+cu121 12.1

# %%
# %cd /content
# !git clone https://github.com/justEhmadSaeed/DCGFM
# %cd /content/DCGFM/OFA
# Out:
# Cloning into 'DCGFM'...
# remote: Enumerating objects: 269, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 269 (delta 10), reused 23 (delta 10), pack-reused 239 (from 1)
# Receiving objects: 100% (269/269), 130.62 MiB | 19.83 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (181/181), done.
# /content/DCGFM/OFA

# %%
# !pip install -r /content/DCGFM/requirements.txt
# Out:
# Collecting lightning==2.5.2 (from -r /content/DCGFM/requirements.txt (line 8))
#   Downloading lightning-2.5.2-py3-none-any.whl.metadata (38 kB)
# Collecting pytorch-lightning==2.5.2 (from -r /content/DCGFM/requirements.txt (line 9))
#   Downloading pytorch_lightning-2.5.2-py3-none-any.whl.metadata (21 kB)
# Collecting torchmetrics==1.6.1 (from -r /content/DCGFM/requirements.txt (line 10))
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting transformers==4.46.3 (from -r /content/DCGFM/requirements.txt (line 12))
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 5.1 MB/s eta 0:00:00
# Collecting datasets==3.2.0 (from -r /content/DCGFM/requirements.txt (line 13))
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Collecting accelerate==1.2.1 (from -r /content/DCGFM/requirements.txt (line 14))
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting peft==0.14.0 (from -r /content/DCGFM/requirements.txt (line 15))
#   Downloading peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting bitsandbytes==0.45.2 (from -r /content/DCGFM/requirements.txt (line 16))
#   Downloading bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Collecting sentence-transformers==3.3.1 (from -r /content/DCGFM/requirements.txt (line 17))
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Collecting sentencepiece==0.2.0 (from -r /content/DCGFM/requirements.txt (line 18))
#   Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting deepspeed==0.16.4 (from -r /content/DCGFM/requirements.txt (line 20))
#   Downloading deepspeed-0.16.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wandb==0.19.8 (from -r /content/DCGFM/requirements.txt (line 21))
#   Downloading wandb-0.19.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch-geometric==2.6.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/DCGFM/requirements.txt (line 23)) (2.6.1)
# Collecting ogb==1.3.6 (from -r /content/DCGFM/requirements.txt (line 24))
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Collecting rdkit==2024.9.6 (from -r /content/DCGFM/requirements.txt (line 26))
#   Downloading rdkit-2024.9.6-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting pympler==1.1 (from -r /content/DCGFM/requirements.txt (line 27))
#   Downloading Pympler-1.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting test-tube==0.7.5 (from -r /content/DCGFM/requirements.txt (line 28))
#   Downloading test_tube-0.7.5.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8))
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging<27.0,>=20.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (26.0)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (2.5.1+cu121)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (4.67.3)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics==1.6.1->-r /content/DCGFM/requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (2.32.4)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12))
#   Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (0.70.16)
# Collecting fsspec<2027.0,>=2022.5.0 (from fsspec[http]<2027.0,>=2022.5.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8))
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (3.13.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.2.1->-r /content/DCGFM/requirements.txt (line 14)) (5.9.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.3.1->-r /content/DCGFM/requirements.txt (line 17)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.3.1->-r /content/DCGFM/requirements.txt (line 17)) (1.16.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.3.1->-r /content/DCGFM/requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (0.8.2)
# Collecting hjson (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20))
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (1.1.2)
# Collecting ninja (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20))
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (2.12.3)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (13.595.45)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (8.3.1)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (4.9.4)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (5.29.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (2.57.0)
# Collecting setproctitle (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21))
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.6.1->-r /content/DCGFM/requirements.txt (line 23)) (3.1.6)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.6.1->-r /content/DCGFM/requirements.txt (line 23)) (3.3.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from ogb==1.3.6->-r /content/DCGFM/requirements.txt (line 24)) (1.17.0)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from ogb==1.3.6->-r /content/DCGFM/requirements.txt (line 24)) (2.5.0)
# Collecting outdated>=0.2.0 (from ogb==1.3.6->-r /content/DCGFM/requirements.txt (line 24))
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (2.37.3)
# Requirement already satisfied: tensorboard>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (2.19.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (1.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (1.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (1.4.2)
# Collecting littleutils (from outdated>=0.2.0->ogb==1.3.6->-r /content/DCGFM/requirements.txt (line 24))
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.2.0->-r /content/DCGFM/requirements.txt (line 13)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed==0.16.4->-r /content/DCGFM/requirements.txt (line 20)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.3->-r /content/DCGFM/requirements.txt (line 12)) (2026.2.25)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers==3.3.1->-r /content/DCGFM/requirements.txt (line 17)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers==3.3.1->-r /content/DCGFM/requirements.txt (line 17)) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15.0->test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15.0->test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15.0->test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15.0->test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15.0->test-tube==0.7.5->-r /content/DCGFM/requirements.txt (line 28)) (3.1.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (3.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning==2.5.2->-r /content/DCGFM/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric==2.6.1->-r /content/DCGFM/requirements.txt (line 23)) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.8->-r /content/DCGFM/requirements.txt (line 21)) (5.0.3)
# Downloading lightning-2.5.2-py3-none-any.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.1/821.1 kB 62.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 65.3 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 71.3 MB/s eta 0:00:00
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 164.5 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 47.0 MB/s eta 0:00:00
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.4/336.4 kB 37.8 MB/s eta 0:00:00
# Downloading peft-0.14.0-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 41.9 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.2-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 39.8 MB/s eta 0:00:00
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.5 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.1 MB/s eta 0:00:00
# Downloading wandb-0.19.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 131.0 MB/s eta 0:00:00
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 9.8 MB/s eta 0:00:00
# Downloading rdkit-2024.9.6-cp312-cp312-manylinux_2_28_x86_64.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 84.2 MB/s eta 0:00:00
# Downloading Pympler-1.1-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 20.1 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 21.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 51.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 112.4 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 6.9 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 23.4 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Building wheels for collected packages: deepspeed, test-tube
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.16.4-py3-none-any.whl size=1562645 sha256=786e58b2cd6b6215898f274122e85c932aad338434161d475602e4867e4df4a6
#   Stored in directory: /root/.cache/pip/wheels/df/4c/09/8ae983e56c326a108b2b9d8671823076456164405dcebe7cb0
#   Building wheel for test-tube (setup.py) ... done
#   Created wheel for test-tube: filename=test_tube-0.7.5-py3-none-any.whl size=25324 sha256=84e2950e9530101e59bb7c5b306fe9a688b7fdb5bda5f0fe60026be637d5e422
#   Stored in directory: /root/.cache/pip/wheels/6d/9d/e9/6356a7f57b54cef60e1c470df2c70b37280abb95f3a3bcefc6
# Successfully built deepspeed test-tube
# Installing collected packages: sentencepiece, hjson, setproctitle, rdkit, pympler, ninja, littleutils, lightning-utilities, fsspec, docker-pycreds, outdated, huggingface-hub, wandb, tokenizers, transformers, torchmetrics, test-tube, ogb, deepspeed, datasets, bitsandbytes, accelerate, sentence-transformers, pytorch-lightning, peft, lightning
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.1
#     Uninstalling sentencepiece-0.2.1:
#       Successfully uninstalled sentencepiece-0.2.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.8.0
#     Uninstalling huggingface_hub-1.8.0:
#       Successfully uninstalled huggingface_hub-1.8.0
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.25.1
#     Uninstalling wandb-0.25.1:
#       Successfully uninstalled wandb-0.25.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.13.0
#     Uninstalling accelerate-1.13.0:
#       Successfully uninstalled accelerate-1.13.0
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.3.0
#     Uninstalling sentence-transformers-5.3.0:
#       Successfully uninstalled sentence-transformers-5.3.0
#   Attempting uninstall: peft
#     Found existing installation: peft 0.18.1
#     Uninstalling peft-0.18.1:
#       Successfully uninstalled peft-0.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed accelerate-1.2.1 bitsandbytes-0.45.2 datasets-3.2.0 deepspeed-0.16.4 docker-pycreds-0.4.0 fsspec-2024.9.0 hjson-3.1.0 huggingface-hub-0.36.2 lightning-2.5.2 lightning-utilities-0.15.3 littleutils-0.2.4 ninja-1.13.0 ogb-1.3.6 outdated-0.2.2 peft-0.14.0 pympler-1.1 pytorch-lightning-2.5.2 rdkit-2024.9.6 sentence-transformers-3.3.1 sentencepiece-0.2.0 setproctitle-1.3.7 test-tube-0.7.5 tokenizers-0.20.3 torchmetrics-1.6.1 transformers-4.46.3 wandb-0.19.8

# %%
# %cd /content/DCGFM/OFA
# %env WANDB_MODE=offline
# !python hf/hf_download.py \
  --model sentence-transformers/multi-qa-distilbert-cos-v1 \
  --save_dir ./cache_data/model \
  --use_mirror False

# !python hf/hf_download.py \
  --dataset haitengzhao/molecule_property_instruction \
  --save_dir ./cache_data/dataset \
  --use_mirror False

# !ls ./cache_data/model
# !ls ./cache_data/dataset
# Out:
# /content/DCGFM/OFA
# env: WANDB_MODE=offline
# Install hf_transfer.
# Collecting hf-transfer
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 115.6 MB/s eta 0:00:00
# Installing collected packages: hf-transfer
# Successfully installed hf-transfer-0.1.9
# export HF_HUB_ENABLE_HF_TRANSFER= 1
# Downloading '.gitattributes' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.8d1395b12188a31e8a22acea211f312d818744e9.incomplete'
# .gitattributes: 100% 791/791 [00:00<00:00, 5.76MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.gitattributes
# Downloading '1_Pooling/config.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/1_Pooling/8_PA_wEVGiVa2goH2H4KQOQpvVY=.4e09f293dfe90bba49f87cfe7996271f07be2666.incomplete'
# config.json: 100% 190/190 [00:00<00:00, 1.66MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/1_Pooling/config.json
# Downloading 'README.md' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.c539a92876a5517ccc9c6da36406e067513ba1b4.incomplete'
# README.md: 9.52kB [00:00, 33.9MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/README.md
# Downloading 'config.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.76eedc94d407a8910196d31121672f4878c008f7.incomplete'
# config.json: 100% 523/523 [00:00<00:00, 5.80MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/config.json
# Downloading 'config_sentence_transformers.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/7FlMl4FxR6n7kBtLngDIJQ5nHiI=.fd1b291129c607e5d49799f87cb219b27f98acdf.incomplete'
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 1.25MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/config_sentence_transformers.json
# Downloading 'data_config.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/x2Rt2861-Bgu_eYvy93NIBMPOFg=.a3294881c9834ac6fb99d420008f30b741fe7e86.incomplete'
# data_config.json: 25.5kB [00:00, 20.4MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/data_config.json
# Downloading 'model.safetensors' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.80098f338a74f94b7f13ae463852aea3735afef5ff0f76c1d31129af6cea9366.incomplete'
# model.safetensors: 100% 265M/265M [00:02<00:00, 119MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/model.safetensors
# Downloading 'modules.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/rqDUs8AfQpUqG2NjnkGNseO9-Z4=.952a9b81c0bfd99800fabf352f69c7ccd46c5e43.incomplete'
# modules.json: 100% 349/349 [00:00<00:00, 4.09MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/modules.json
# Downloading 'onnx/model.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/ihhw_uFzBe-Y54_HOJQmXx4GS8A=.11cfe071068b6857e9323f73883079e9d720b6672c6092d894c29ed4bdfa353d.incomplete'
# onnx/model.onnx: 100% 266M/266M [00:01<00:00, 147MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model.onnx
# Downloading 'onnx/model_O1.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/Jz1dqTRkC9OqrRVBoUUgJasE5D4=.e64351e5e608d17e7e24335c74d83794ec6a273b9a70fee19a669794729d03bd.incomplete'
# onnx/model_O1.onnx: 100% 266M/266M [00:01<00:00, 165MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_O1.onnx
# Downloading 'onnx/model_O2.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/fhmtN5lr2pRcTsN4JIXHvpvTfsQ=.97b49bb982bff6b4d3cb963b2cb4ef2b4ef038338f77f128375c52f5ed0c608e.incomplete'
# onnx/model_O2.onnx: 100% 265M/265M [00:01<00:00, 147MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_O2.onnx
# Downloading 'onnx/model_O3.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/C5VJXYd7xfrcGI6qO6pWSgfb2iA=.52c3ba099bce8809cd15c1cafd12032e908f2a8ab55330c55e6c6e4c71427796.incomplete'
# onnx/model_O3.onnx: 100% 265M/265M [00:01<00:00, 165MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_O3.onnx
# Downloading 'onnx/model_O4.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/8M5G_GF35MrvaVa65iMMHJv3fIA=.290103d8f24888fd3ce574951bd34acb8512efcc4b1f0e5f2c54c68c639cdd2d.incomplete'
# onnx/model_O4.onnx: 100% 133M/133M [00:01<00:00, 82.4MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_O4.onnx
# Downloading 'onnx/model_qint8_arm64.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/XSZ-efieuvtPx3j1uS5YppO_UUo=.452acb3a0d654b6842a18c6d91d9662c9ec81db286ef24087cfd66540539c2d1.incomplete'
# onnx/model_qint8_arm64.onnx: 100% 67.0M/67.0M [00:00<00:00, 82.6MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_qint8_arm64.onnx
# Downloading 'onnx/model_qint8_avx512.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/vkIANGfBQsH4ABb2nI_WlgN4dn4=.452acb3a0d654b6842a18c6d91d9662c9ec81db286ef24087cfd66540539c2d1.incomplete'
# onnx/model_qint8_avx512.onnx: 100% 67.0M/67.0M [00:00<00:00, 110MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_qint8_avx512.onnx
# Downloading 'onnx/model_qint8_avx512_vnni.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/WpaTElq6uGDhP7vAplvKxvF90ek=.452acb3a0d654b6842a18c6d91d9662c9ec81db286ef24087cfd66540539c2d1.incomplete'
# onnx/model_qint8_avx512_vnni.onnx: 100% 67.0M/67.0M [00:00<00:00, 110MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_qint8_avx512_vnni.onnx
# Downloading 'onnx/model_quint8_avx2.onnx' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/onnx/DkWusgf06FSZDVV1Q4a480SyGlg=.4f28db0eea7ebd3a0f50139261208fb82a5b718eb1b643e0af5ac5e27f94f741.incomplete'
# onnx/model_quint8_avx2.onnx: 100% 67.0M/67.0M [00:00<00:00, 82.7MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/onnx/model_quint8_avx2.onnx
# Downloading 'openvino/openvino_model.bin' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/openvino/SAxurrcy-4m-l5PAwlLF8JFD92I=.c9f1feab0026bba1bfbf645c84822c578bdf5f18e493891f27c462b61334a72d.incomplete'
# openvino/openvino_model.bin: 100% 265M/265M [00:02<00:00, 132MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/openvino/openvino_model.bin
# Downloading 'openvino/openvino_model.xml' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/openvino/RHtQiE8mUsJXT1ACniRNFX2H1R4=.e27aba84eea444b1950931f964949be30a7e023c.incomplete'
# openvino_model.xml: 218kB [00:00, 239MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/openvino/openvino_model.xml
# Downloading 'openvino/openvino_model_qint8_quantized.bin' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/openvino/5sXxy3T6xtaD5oz1H_aX4KjEPgQ=.abee7b59f1c70d43da7482e2ff0d4023283ffccd5a4b9b51b8dc6ea4d39fa5c6.incomplete'
# openvino/openvino_model_qint8_quantized.(…): 100% 67.0M/67.0M [00:00<00:00, 82.6MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/openvino/openvino_model_qint8_quantized.bin
# Downloading 'openvino/openvino_model_qint8_quantized.xml' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/openvino/QnL_Hg8_Eqaf3xzWBW1kwNT1rMU=.0d5c9158345cea7f20c6b8053f4fe1b9f91a982d.incomplete'
# openvino_model_qint8_quantized.xml: 372kB [00:00, 309MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/openvino/openvino_model_qint8_quantized.xml
# Downloading 'pytorch_model.bin' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/Q1p2l2BzM1m6P5jKvr8WTq1TUio=.f5c0bf4fc2877aeea22f32ccc58371ee0e860753a5e19b40ded71eea4a3a3656.incomplete'
# pytorch_model.bin: 100% 265M/265M [00:01<00:00, 165MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/pytorch_model.bin
# Downloading 'sentence_bert_config.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/lGVMDuXJ-eOxWaZOviD6MtO-75w=.f789d99277496b282d19020415c5ba9ca79ac875.incomplete'
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 637kB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/sentence_bert_config.json
# Downloading 'special_tokens_map.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.e7b0375001f109a6b8873d756ad4f7bbb15fbaa5.incomplete'
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 1.24MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/special_tokens_map.json
# Downloading 'tokenizer.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.9c190aac0fb9edc2293b69b82c6d5d5d21e67dd9.incomplete'
# tokenizer.json: 466kB [00:00, 109MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/tokenizer.json
# Downloading 'tokenizer_config.json' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.4036a93f3f40a3f79923bb26f5e9a13e0b2d1687.incomplete'
# tokenizer_config.json: 100% 333/333 [00:00<00:00, 4.03MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/tokenizer_config.json
# Downloading 'train_script.py' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/WVoL7XhpU3FxrnFpNM2RbMmfULg=.09e62311249d3aab9bcb1a4acf47aedca9ebe93a.incomplete'
# train_script.py: 13.8kB [00:00, 52.0MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/train_script.py
# Downloading 'vocab.txt' to 'cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/.cache/huggingface/download/E2zehc7lrIVb8gRdx7qjK54iiZY=.fb140275c155a9c7c5a3b3e0e77a9e839594a938.incomplete'
# vocab.txt: 232kB [00:00, 121MB/s]
# Download complete. Moving file to cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1/vocab.txt
# /content/DCGFM/OFA/cache_data/model/models--sentence-transformers--multi-qa-distilbert-cos-v1
# export HF_HUB_ENABLE_HF_TRANSFER= 1
# Downloading '.gitattributes' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a27f169e8e840d36567bbde33f53bd56dd4f7fba.incomplete'
# .gitattributes: 9.77kB [00:00, 36.3MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.gitattributes
# Downloading 'README.md' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.d754083cb66622f76ca67fe8729c37847b4e19eb.incomplete'
# README.md: 1.52kB [00:00, 8.32MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/README.md
# Downloading 'data/bace-00000-of-00001-93b776500fb5866e.parquet' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data/GuqdguuRA4xmUTm8oAkwwcA0sgQ=.f02a2f467ce4e1ba52793be8886f616418278710.incomplete'
# (…)-00000-of-00001-93b776500fb5866e.parquet: 100% 56.4k/56.4k [00:00<00:00, 155MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/data/bace-00000-of-00001-93b776500fb5866e.parquet
# Downloading 'data/bbbp-00000-of-00001-c7204e683af28451.parquet' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data/RE-72gQAJ1X111h9nKZo4J4m8dU=.bbeb59e02f2c4ce2680fe973e091b178b68cd103.incomplete'
# (…)-00000-of-00001-c7204e683af28451.parquet: 100% 80.4k/80.4k [00:00<00:00, 234MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/data/bbbp-00000-of-00001-c7204e683af28451.parquet
# Downloading 'data/chembl_pretraining-00000-of-00025-6a6e3f179bcd16a5.parquet' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data/MPxDXrRRwbcm9zlBV7XEr5ZkN3c=.a7a217b69bc2fa121c414e2ab090c6068d27ef3462d1d97cd9965d24170afd35.incomplete'
# data/chembl_pretraining-00000-of-00025-6(…): 100% 36.0M/36.0M [00:01<00:00, 25.3MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/data/chembl_pretraining-00000-of-00025-6a6e3f179bcd16a5.parquet
# Downloading 'data/chembl_pretraining-00001-of-00025-832e6b98ba0e3e46.parquet' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data/SReYOm36zCBgpWJYPl_PV6oNLAs=.1ad101dd7d74cb8c6083f53a02200ea3256b76d13d68498ba9777eb60459329e.incomplete'
# data/chembl_pretraining-00001-of-00025-8(…): 100% 36.0M/36.0M [00:00<00:00, 44.5MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/data/chembl_pretraining-00001-of-00025-832e6b98ba0e3e46.parquet
# Downloading 'data/chembl_pretraining-00002-of-00025-f23322af2a57add9.parquet' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data/rdpOLPGsip9Uni4_ZVl8VRCpnWA=.c2f1638ddd468f81171d9507e669e238153343f89a66ed55ccfae11c63d59d1a.incomplete'
# data/chembl_pretraining-00002-of-00025-f(…): 100% 36.0M/36.0M [00:00<00:00, 44.4MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/data/chembl_pretraining-00002-of-00025-f23322af2a57add9.parquet
# Downloading 'data/chembl_pretraining-00003-of-00025-50d394a42da4e3d5.parquet' to 'cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data
ache_data/dataset/datasets--haitengzhao--molecule_property_instruction/.cache/huggingface/download/data/aban_3DmBZ8Yffz-QpeRH192vT0=.f486b2d3f333d4d4a6c1179249c4f7e238720ec696ab8b861d1423a91e4b0598.incomplete'
# data/toxcast-00003-of-00004-1eec8c034c03(…): 100% 12.9M/12.9M [00:00<00:00, 31.6MB/s]
# Download complete. Moving file to cache_data/dataset/datasets--haitengzhao--molecule_property_instruction/data/toxcast-00003-of-00004-1eec8c034c039f6c.parquet
# /content/DCGFM/OFA/cache_data/dataset/datasets--haitengzhao--molecule_property_instruction
# models--sentence-transformers--multi-qa-distilbert-cos-v1
# datasets--haitengzhao--molecule_property_instruction

# %%
import os, torch
tv = torch.__version__.split("+")[0]
cv = f"cu{torch.version.cuda.replace('.', '')}"
idx = f"https://data.pyg.org/whl/torch-{tv}+{cv}.html"
os.system(f"pip install -q pyg_lib torch_scatter torch_sparse torch_cluster -f {idx}")
# Out:
# 0

# %%
# SMOKE TEST RUN

# %cd /content/DCGFM/OFA

import os
import torch

gpu_ids = ",".join(str(i) for i in range(torch.cuda.device_count()))
if not gpu_ids:
    raise RuntimeError("No GPU detected. Switch Colab runtime to GPU first.")

os.environ["CUDA_VISIBLE_DEVICES"] = gpu_ids
print("Using GPUs:", gpu_ids)


# !python run_cdm.py \
  --control_gpu \
  --gpus {gpu_ids} \
  --override yamls/soft_and_hard.yaml \
  --hard_pruning_mode hard_prune_api \
  --hard_pruning_joint \
  --hard_pruning_reverse \
  --hard_pruning_ratio 0.3 \
  --prune_ratio 0.3 \
  --fs_sample_size 2000 \
  --checkpoint_interval 1 \
  num_epochs 2 \
  hard_pruning_epochs 2 \
  batch_size 32 \
  eval_batch_size 32 \
  offline_log true
# Out:
# /content/DCGFM/OFA
# Using GPUs: 0
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2026-04-13 21:32:02.844020: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-13 21:32:02.862139: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776115922.884681   12235 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776115922.891426   12235 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776115922.908547   12235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776115922.908585   12235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776115922.908603   12235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776115922.908610   12235 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-13 21:32:02.913617: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-04-13 21:32:08,229] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# namespace(num_bases=4, emb_dim=768, num_layers=5, dropout=0.0, JK='none', lr=0.0005, l2=0, num_epochs=2, batch_size=32, num_workers=4, seed=1, data_path=None, offline_log=True, exp_name='OFA_soft_and_hard_dcgfm_hard_prune_api_2_0.3_0.3', train_sample_size=-1, eval_sample_size=-1, rwpe=None, task_names=['arxiv_fs', 'FB15K237_fs', 'mol_fs'], llm_name='ST', llm_b_size=1, load_texts=False, max_nodes_per_hop=100, load_best=False, test_rep=10, val_interval=1, eval_batch_size=32, d_multiple=[1, 1, 1], d_min_ratio=[1, 1, 1], reload_freq=0, limit_val_batches=0, checkpoint_interval=10, fs_sample_size=12000, hard_pruning_epochs=2, override='yamls/soft_and_hard.yaml', opts=['num_epochs', '2', 'hard_pruning_epochs', '2', 'batch_size', '32', 'eval_batch_size', '32', 'offline_log', 'true'], control_gpu=True, gpus=[0], save_model=False, big_data_cache_dir='./cache_data/ofa_dataset', use_onecycle=False, max_lr=0.05, div_factor=25, final_div=10000, pct_start=0.3, prune_ratio=0.3, delta=1.0, hard_pruning_mode='hard_prune_api', hard_pruning_ratio=0.3, hard_pruning_joint=True, hard_pruning_reverse=True, exp_dir='./saved_exp/2026-04-13 21:32:11.543140', log_project='OFA_dcgfm')
# Using GPU: [0]
# GPU size: 1
# Processing...
# Downloading http://snap.stanford.edu/ogb/data/nodeproppred/arxiv.zip
# Downloaded 0.08 GB: 100% 81/81 [00:13<00:00,  5.79it/s]
# Extracting cache_data/arxiv/ST/arxiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100% 1/1 [00:00<00:00, 20460.02it/s]
# Converting graphs into PyG objects...
# 100% 1/1 [00:00<00:00, 1722.51it/s]
# Saving...
# Done!
# /usr/local/lib/python3.12/dist-packages/ogb/nodeproppred/dataset_pyg.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# /usr/local/lib/python3.12/dist-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# Batches:  15% 24750/169343 [02:07<12:42, 189.54it/s]

# %%
# FULL Configuration

# %cd /content/DCGFM/OFA

import os
import torch

gpu_ids = ",".join(str(i) for i in range(torch.cuda.device_count()))
if not gpu_ids:
    raise RuntimeError("No GPU detected. Switch Colab runtime to GPU first.")

os.environ["CUDA_VISIBLE_DEVICES"] = gpu_ids
print("Using GPUs:", gpu_ids)

# !python run_cdm.py \
  --control_gpu \
  --gpus {gpu_ids} \
  --save_model \
  --override yamls/soft_and_hard.yaml \
  --hard_pruning_mode hard_prune_api \
  --hard_pruning_joint \
  --hard_pruning_reverse \
  --hard_pruning_ratio 0.3 \
  --prune_ratio 0.3 \
  offline_log true
# Out:
# /content/DCGFM/OFA
# Using GPUs: 0
# 2026-04-13 18:28:01.135031: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-13 18:28:01.152957: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776104881.175717   35601 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776104881.182889   35601 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776104881.207444   35601 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776104881.207489   35601 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776104881.207492   35601 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776104881.207495   35601 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-13 18:28:01.214404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-04-13 18:28:07,359] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# usage: run_cdm.py [-h] [--override OVERRIDE] [--control_gpu] [--gpus GPUS]
#                   [--fs_sample_size FS_SAMPLE_SIZE] [--save_model]
#                   [--big_data_cache_dir BIG_DATA_CACHE_DIR]
#                   [--checkpoint_interval CHECKPOINT_INTERVAL] [--use_onecycle]
#                   [--max-lr MAX_LR] [--div-factor DIV_FACTOR]
#                   [--final-div FINAL_DIV] [--pct-start PCT_START]
#                   [--prune_ratio PRUNE_RATIO] [--delta DELTA]
#                   [--hard_pruning_mode HARD_PRUNING_MODE]
#                   [--hard_pruning_ratio HARD_PRUNING_RATIO]
#                   [--hard_pruning_epochs HARD_PRUNING_EPOCHS]
#                   [--hard_pruning_joint] [--hard_pruning_reverse]
#                   ...
# run_cdm.py: error: argument --hard_pruning_ratio: invalid float value: '0.3/0.5/0.7'
